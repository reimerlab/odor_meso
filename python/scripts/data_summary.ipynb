# %% [markdown]
# # Summary notebook
# This notebook is used to determine if all data is populated for the `at-database` to `jr-database` transfer.

# %%
import os
import datajoint as dj
dj.config['database.prefix'] = os.environ.get('DJ_PREFIX', '')
from pipeline import mice, experiment, meso, odor, treadmill

# %% [markdown]
# ---

# %%
mice.Mice.proj()
# Out:
# *animal_id
# +-----------+
# 118
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 1387
# 1523
# 1529
# 1542
#    ...
#  (Total: 18)

# %%
experiment.Session.proj()
# Out:
# *animal_id    *session
# +-----------+ +---------+
# 118           1
# 118           2
# 120           1
# 121           1
# 121           2
# 121           3
# 121           4
# 121           5
# 121           6
# 121           7
# 121           8
# 122           1
#    ...
#  (Total: 51)

# %%
experiment.Session.proj() - odor.MesoMatch()
# Out:
# *animal_id    *session
# +-----------+ +---------+
# 118           1
# 118           2
# 120           1
# 121           1
# 121           2
# 121           3
# 121           4
# 121           5
# 121           6
# 121           8
# 122           2
# 122           5
#    ...
#  (Total: 38)

# %%
experiment.Scan.proj()
# Out:
# *animal_id    *session    *scan_idx
# +-----------+ +---------+ +----------+
# 118           2           1
# 120           1           1
# 120           1           2
# 120           1           3
# 121           7           1
# 121           7           2
# 121           7           3
# 122           1           4
# 122           3           1
# 122           4           4
# 122           6           2
# 122           8           1
#    ...
#  (Total: 47)

# %%
experiment.Scan.proj() - odor.MesoMatch()
# Out:
# *animal_id    *session    *scan_idx
# +-----------+ +---------+ +----------+
# 118           2           1
# 120           1           1
# 120           1           2
# 120           1           3
# 124           3           2
# 124           3           3
# 124           3           6
# 124           5           1
# 124           5           2
# 124           6           1
# 124           9           1
# 126           1           1
#    ...
#  (Total: 31)

# %%
experiment.AutoProcessing()
# Out:
# *animal_id    *session    *scan_idx    priority     autosegment
# +-----------+ +---------+ +----------+ +----------+ +------------+
# 121           7           1            0            0
# 121           7           2            0            0
# 121           7           3            0            0
# 122           1           4            0            0
# 122           3           1            0            0
# 122           4           4            0            0
# 122           6           2            0            0
# 122           8           1            0            0
# 123           1           1            0            0
# 124           1           1            0            0
# 124           2           1            0            0
# 124           3           1            0            0
#    ...
#  (Total: 17)

# %%
experiment.AutoProcessing() - odor.MesoMatch()
# Out:
# *animal_id    *session    *scan_idx    priority     autosegment
# +-----------+ +---------+ +----------+ +----------+ +------------+
# 124           9           1            0            0
#  (Total: 1)

# %%
experiment.AutoProcessing.proj() - meso.ScanInfo.proj()
# Out:
# *animal_id    *session    *scan_idx
# +-----------+ +---------+ +----------+
#
#  (Total: 0)

# %%
experiment.AutoProcessing.proj() - meso.Quality()
# Out:
# *animal_id    *session    *scan_idx
# +-----------+ +---------+ +----------+
#
#  (Total: 0)

# %%
meso.ScanInfo.Field.proj() - meso.CorrectionChannel.proj()
# Out:
# *animal_id    *session    *scan_idx    *pipe_version  *field
# +-----------+ +---------+ +----------+ +------------+ +-------+
#
#  (Total: 0)

# %%
meso.ScanInfo.Field.proj() - meso.RasterCorrection.proj()
# Out:
# *animal_id    *session    *scan_idx    *pipe_version  *field
# +-----------+ +---------+ +----------+ +------------+ +-------+
#
#  (Total: 0)

# %%
meso.ScanInfo.Field.proj() - meso.MotionCorrection.proj()
# Out:
# *animal_id    *session    *scan_idx    *pipe_version  *field
# +-----------+ +---------+ +----------+ +------------+ +-------+
#
#  (Total: 0)

# %%
experiment.AutoProcessing.proj() - meso.Stitch.proj()
# Out:
# *animal_id    *session    *scan_idx
# +-----------+ +---------+ +----------+
# 121           7           1
# 121           7           2
# 121           7           3
# 122           1           4
# 122           3           1
# 122           4           4
# 122           6           2
# 122           8           1
# 123           1           1
# 124           1           1
# 124           2           1
# 124           3           1
#    ...
#  (Total: 17)

# %%
meso.CorrectionChannel() - meso.SummaryImages()
# Out:
# *animal_id    *session    *scan_idx    *field    channel
# +-----------+ +---------+ +----------+ +-------+ +---------+
# 118           2           1            1         1
# 118           2           1            2         1
# 118           2           1            3         1
# 120           1           1            1         1
# 120           1           1            2         1
# 120           1           1            3         1
# 120           1           1            4         1
# 120           1           2            1         1
# 120           1           2            2         1
# 120           1           2            3         1
# 120           1           2            4         1
# 120           1           3            1         1
#    ...
#  (Total: 91)

# %%
meso.SegmentationTask.proj() - meso.Segmentation.proj()
# Out:
# *animal_id    *session    *scan_idx    *field    *channel    *segmentation_
# +-----------+ +---------+ +----------+ +-------+ +---------+ +------------+
# 118           2           1            1         1           1
# 120           1           1            1         1           1
# 120           1           2            1         1           1
# 120           1           2            1         1           2
# 120           1           3            1         1           1
# 1387          2           2            1         1           1
# 1387          2           3            1         1           1
# 1387          2           5            1         1           1
# 1387          2           6            1         1           1
# 1387          2           7            1         1           1
# 1523          1           2            1         1           1
# 1523          2           1            1         1           1
#    ...
#  (Total: 98)

# %%
meso.SegmentationTask.proj() - meso.Fluorescence.proj()
# Out:
# *animal_id    *session    *scan_idx    *field    *channel    *segmentation_
# +-----------+ +---------+ +----------+ +-------+ +---------+ +------------+
# 118           2           1            1         1           1
# 120           1           1            1         1           1
# 120           1           2            1         1           1
# 120           1           2            1         1           2
# 120           1           3            1         1           1
# 124           3           4            1         1           1
# 1387          2           2            1         1           1
# 1387          2           3            1         1           1
# 1387          2           5            1         1           1
# 1387          2           6            1         1           1
# 1387          2           7            1         1           1
# 1523          1           2            1         1           1
#    ...
#  (Total: 100)

# %%
meso.MaskClassification()
# Out:
# *animal_id    *session    *scan_idx    *pipe_version  *field    *channel    *segmentation_ *classificatio classif_time
# +-----------+ +---------+ +----------+ +------------+ +-------+ +---------+ +------------+ +------------+ +------------+
#
#  (Total: 0)

# %%
meso.SegmentationTask.proj() - meso.ScanSet.proj()
# Out:
# *animal_id    *session    *scan_idx    *field    *channel    *segmentation_
# +-----------+ +---------+ +----------+ +-------+ +---------+ +------------+
# 118           2           1            1         1           1
# 120           1           1            1         1           1
# 120           1           2            1         1           1
# 120           1           2            1         1           2
# 120           1           3            1         1           1
# 121           7           1            1         1           1
# 121           7           2            1         1           1
# 121           7           3            1         1           1
# 122           1           4            1         1           1
# 122           3           1            1         1           1
# 122           4           4            1         1           1
# 122           6           2            1         1           1
#    ...
#  (Total: 145)

# %%
meso.Activity()
# Out:
# *animal_id    *session    *scan_idx    *pipe_version  *field    *channel    *segmentation_ *spike_method  activity_time
# +-----------+ +---------+ +----------+ +------------+ +-------+ +---------+ +------------+ +------------+ +------------+
#
#  (Total: 0)

# %%
meso.ScanDone()
# Out:
# *animal_id    *session    *scan_idx    *pipe_version  *segmentation_ *spike_method
# +-----------+ +---------+ +----------+ +------------+ +------------+ +------------+
#
#  (Total: 0)

# %%
experiment.AutoProcessing.proj() - treadmill.Treadmill.proj()
# Out:
# *animal_id    *session    *scan_idx
# +-----------+ +---------+ +----------+
# 124           5           3
#  (Total: 1)

# %%
odor.OdorRecording.proj() - odor.MesoMatch()
# Out:
# *animal_id    *odor_session  *recording_idx
# +-----------+ +------------+ +------------+
# 118           1              0
# 120           0              0
# 120           1              1
# 120           2              2
# 1387          2              2
# 1387          2              3
# 1387          2              5
# 1387          2              6
# 1387          2              7
# 1523          4              2
# 1523          5              3
# 1529          3              3
#    ...
#  (Total: 23)

# %%
odor.MesoMatch.proj() - odor.OdorTrials()
# Out:
# *animal_id    *odor_session  *recording_idx
# +-----------+ +------------+ +------------+
# 122           0              0
#  (Total: 1)

# %%
odor.MesoMatch.proj() - odor.OdorSync.proj()
# Out:
# *animal_id    *odor_session  *recording_idx
# +-----------+ +------------+ +------------+
# 121           9              9
# 122           0              0
# 122           7              13
# 124           0              0
# 124           1              1
# 124           6              6
#  (Total: 6)

# %%
odor.MesoMatch.proj() - odor.Respiration.proj()
# Out:
# *animal_id    *odor_session  *recording_idx
# +-----------+ +------------+ +------------+
# 121           8              8
# 122           0              0
#  (Total: 2)

# %%
experiment.ExperimentalIdentifier() - odor.OdorAnalysis()
# Out:
# *experiment_id animal_id     session     scan_idx
# +------------+ +-----------+ +---------+ +----------+
# 1              121           7           1
# 2              121           7           2
# 3              121           7           3
# 4              122           1           4
# 5              122           3           1
# 6              122           4           4
# 7              122           6           2
# 8              122           8           1
# 9              123           1           1
# 10             124           1           1
# 11             124           2           1
# 12             124           3           1
#    ...
#  (Total: 17)

# %%
experiment.ExperimentalIdentifier() - odor.SummaryImageSet()
# Out:
# *experiment_id animal_id     session     scan_idx
# +------------+ +-----------+ +---------+ +----------+
# 1              121           7           1
# 2              121           7           2
# 3              121           7           3
# 4              122           1           4
# 5              122           3           1
# 6              122           4           4
# 7              122           6           2
# 8              122           8           1
# 9              123           1           1
# 10             124           1           1
# 11             124           2           1
# 12             124           3           1
#    ...
#  (Total: 17)

# %%
# TODO: add stack pipeline
